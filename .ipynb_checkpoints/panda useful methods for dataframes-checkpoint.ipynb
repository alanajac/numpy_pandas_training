# %%
#Lets do this!
#First for single columns and then to multiple columns
import pandas as pd, numpy as np
df=pd.read_csv('tips.csv')
df.info
#Lets do an example. Lets get the last 4 numbers of the credit card.
#But we see that the credit card number is registered as an int, and not as an integer.
#So its difficult to do it. :D We need to first convert it for a string and then get the last 4 numbers of
#the credit card. Lets define a function for that:
def last_four(cc_number):
    return str(cc_number)[-4:]
#Using apply we can use a function to be applied to the data frame!

df['last_four']=df['CC Number'].apply(last_four)
df
print(df['total_bill'].mean())
def yelp(price):
    if price<10:
        return '$'
    elif price>=10 and price <30:
        return '$$'
    else: 
        return '$$$'
df
df['expenses']=df['total_bill'].apply(yelp)
#apply is a single value function. Which is applied to every row. :)

df
#NOW MULTIPLE COLUMNS FUNCTIONS!
#First lets use lambda expressions
#the function
def multiply_by_two(num):
    return num*2
#wen can represented by
lambda num:num*2
#So we can do something like:
df['total_bill'].apply(lambda num:num*2)
df
#lets create a new function
def quality(total_bill,tip):
    if tip/total_bill>0.25:
        return 'generous'
    else: return 'other'
    
#testing...
quality(17.01,1.99)
#Now lets apply this function using the apply method
#Check the typos. The first argument of function applied is quality, and the second is axis=1 -> columns
df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)
#we can now add the column to the data_frame
df['quality']=df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)
df
# Out:
# 19.785942622950824
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
#We can do it in a simpler way:
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])
#np.vectorize will help us with gain/efficiency
#Lets check how fast is the difference!
import timeit
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
#Lets try another methods. We used timeit
#Lets read again the same table:
#we can use apply to do the transformation of the integer to string.
#Lets check which one is the fastest
setup='''
import numpy as np
import pandas as pd
df=pd.read_csv('tips.csv')
'''

com1='''
df['CC_Number']=df['CC Number'].apply(str)
'''
com2='''
df['CC_Number']=df['CC Number'].map(str)
'''
print(timeit.timeit(setup=setup,stmt=com1,number=1000 ))
print(timeit.timeit(setup=setup,stmt=com2,number=1000 ))
#map is faster to do the calculation than apply!:D
# Out:
# 0.27070629911031574
# 0.16161052999086678

# %%
#Now lets ddo what they do
#First thing: sort the data frame
import pandas as pd
import numpy as np
df=pd.read_csv("tips.csv")
df
#First method. sorting values
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#We can sort by more than one column:
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#We can also grab the index locations. For example:
print(df['total_bill'].max())
#Or the index of the max location
df['total_bill'].idxmax()
# Out:
# 50.81
# 170

# %%
#We can also do correlation between all the columns
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
#Another thing that can be done...To calculate the number of the elements of different categories
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
#And also the number of unique values.
df['day'].nunique()
#This one shows which are the days
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
#Lets check for other columns
df['tip'].nunique()
# Out:
# 123

# %%
#We can also replace or map a change in a data frame. 
#Examples:
df=pd.read_csv("tips.csv")
df
#df['sex'].replace('Female','F')
#And do more than one
df['sex']=df['sex'].replace(['Female','Male'],['F','M'])
df
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 239    NaN
# 240    NaN
# 241    NaN
# 242    NaN
# 243    NaN
# Name: sex, Length: 244, dtype: object

# %%
#Lets now understand the map functionality
df=pd.read_csv("tips.csv")
my_map={'Female':'F','Male':'M'}
df['sex'].map(my_map)

#We can also check for duplicates!
#Lets check a data frame with duplicates
simple_pf=pd.DataFrame([1,2,2,2],['a','b','c','d'])
simple_pf.duplicated()
#Very good cleaning duplicate data
simple_pf.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
#Now tbetween
df['average bill']=df['total_bill'].between(10,20,inclusive=True)
#Inclusive are going to be changed for both or neither.
df

#Another method:
#Gives me the n-instances which have the highest value of one parameter/column
df.nlargest(10,'tip')
#And of course we can also write: - And this way is faster.
df.sort_values('tip',ascending=False).iloc[0:2]
#And there is also .nsmallest.
# Out:
# /tmp/ipykernel_1500690/2289957442.py:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['average bill']=df['total_bill'].between(10,20,inclusive=True)
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID  average bill
# 170    Gregory Clark  5473850968388236    Sat1954         False
# 212  Alex Williamson      676218815212    Sat4590         False

# %%
#ANother method os sample!
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2              7.69
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2             17.32
#
#         Payer Name         CC Number Payment ID  average bill
# 75   Kenneth Hayes   213142079731108    Sat5056          True
# 145      Amy Young     4285454264477   Thur9331         False
# 101  Tiffany Colon  6011012799432041    Fri8382          True
# 190   Riley Barnes   180053549128800    Sun5104          True
# 179   Brian Bailey   346656312114848    Sun9851         False

# %%
import pandas as pd, numpy as np
df=pd.read_csv('tips.csv')
#It gets random values
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 68        20.23  2.01    Male     No   Sat  Dinner     2             10.12
# 162       16.21  2.00  Female     No   Sun  Dinner     3              5.40
# 99        12.46  1.50    Male     No   Fri  Dinner     2              6.23
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3             15.12
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2             14.22
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2             16.45
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2              8.76
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2              7.74
# 123       15.95  2.00    Male     No  Thur   Lunch     2              7.98
# 132       11.17  1.50  Female     No  Thur   Lunch     2              5.58
# ...
